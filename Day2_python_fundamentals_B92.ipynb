# %%
Duration ====> 4 weeks program

Mon - Friday ====> 8pm - IST to 8.45 pm - IST

No recording will be made, all of you have to join in the live session.

Do take the running notes.

# %%
Introduction to python fundamentals :

# %%
understanding the variables in python :

# %%
x = 2

y = 3

# %%
z = x+y

print(z)
# Out:
# 5

# %%
Rules for declaring the variables :

# %%
Rule no 1 : No Namespaces while declaring the variable

# %%
first name = 'Faiyaz'

print(first name)
# Out:
#   Input In [3]
#     first name = 'Faiyaz'
#           ^
# SyntaxError: invalid syntax

# %%
firstname = 'Faiyaz'

print(firstname)
# Out:
# Faiyaz

# %%
first_name = 'Faiyaz'

print(first_name)
# Out:
# Faiyaz

# %%
Rule No 2 : A variable name should not start with a number **

# %%
1name = 'tushar'

print(1name)
# Out:
#   Input In [6]
#     1name = 'tushar'
#      ^
# SyntaxError: invalid syntax

# %%
name1 = 'tushar'

print(name1)
# Out:
# tushar

# %%
Rule No 3 : A variable  name should not contain any special characters
    
    @ # $ % ^ &

# %%
name@ = 'santosh'

print(name@)
# Out:
#   Input In [8]
#     name@ = 'santosh'
#           ^
# SyntaxError: invalid syntax

# %%
introduction to datatypes :
    
    1. strings =========> str
    
    2. numbers ======> integers -------> int and floats( decimals) ---> 0.1,0.2 ===> float
    
    3. lists ===> list
    
    4. tuples===> tuple
    
    5. Dictionary =====> dict

# %%
classification of datatypes :
    
    Broadly datatypes are classified in to two categeroeis :
        
        1. mutable datatypes ===> these are flexible in nature ===> which we can edit and alter
        
        2. immutable datatype==> these are fixed in nature ===> which we cannot be able to edit and alter

# %%
introduction to string datatype :
    
defination : A string is a series of characters declared in quotes.
    
classification : It is classified as an immutable datatype
    
how to declare the string ..........?

2 approaches :
    
    1. single quote
    
    2. double quote
# Out:
#   Input In [13]
#     introduction to string datatype :
#                  ^
# SyntaxError: invalid syntax

# %%
firstname = 'sekhar'   #single quote

print(firstname)
# Out:
# sekhar

# %%
name = "zainab"  # double quotes

print(name)
# Out:
# zainab

# %%
introduction to string methods :

# %%
type(firstname)
# Out:
# str

# %%
type(name)
# Out:
# str

# %%
Note : 1 Python is a case senstive langauge

# %%
# is used to comment the code.

# %%
fullname = 'durga prasad'

print(fullname)
# Out:
# durga prasad

# %%
print(fullname.title())
# Out:
# Durga Prasad

# %%
# req: i want the entire name in capital letters.

# %%
print(fullname.upper())
# Out:
# DURGA PRASAD

# %%
# req: i want the entire name in small letters.

# %%
print(fullname.lower())
# Out:
# durga prasad

# %%
Steps to download :
    
    file ----> donwload as ----> notebook.ipynb ====> downloads path.

# %%
github ---> open repository and upload it there.

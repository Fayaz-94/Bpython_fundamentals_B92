# %%
continuation with string datatype :

# %%
introduction to f strings :

# %%
# Genral syntax of f strings :

# %%
f" custom message  {place_holder_1} {place_holder_2}........{place_holder_n}"

# %%
firstname = "David"

lastname = "john"

# %%
# req: i want to get the full name....?

# %%
fullname = f"{firstname} {lastname}"

print(fullname)
# Out:
# David john

# %%
message = f"keep up the good work, {fullname}"

print(message)
# Out:
# keep up the good work, David john

# %%
type(fullname)
# Out:
# str

# %%
# adding whitespaces to strings :

# %%
# req :

# %%
print("fav_porgramming_lang:pythonc++javacjavascriptswift")
# Out:
# fav_porgramming_lang:pythonc++javacjavascriptswift

# %%
print("fav_porgramming_lang:\npython\nc++\njava\nc\njavascript\nswift")  # \n ---> new line delimiter
# Out:
# fav_porgramming_lang:
# python
# c++
# java
# c
# javascript
# swift

# %%
print("fav_porgramming_lang:\n\tpython\n\tc++\n\tjava\n\tc\n\tjavascript\n\tswift") # \t ---> tab delimiter
# Out:
# fav_porgramming_lang:
# 	python
# 	c++
# 	java
# 	c
# 	javascript
# 	swift

# %%
Removing whitespaces from the strings :

# %%
name = '  python'  # left side.

print(name)
# Out:
#   python

# %%
name2 = 'python'

print(name2)
# Out:
# python

# %%
name3 = 'python  '

print(name3)
# Out:
# python

# %%
name.lstrip()  # left strip
# Out:
# 'python'

# %%
name3.rstrip()
# Out:
# 'python'

# %%
name4 = "  python  "

print(name4)
# Out:
#   python

# %%
name4.strip()
# Out:
# 'python'
